# %% [markdown]
# <a href="https://colab.research.google.com/github/saichikane/sai/blob/master/ramacarservices%20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# loading dataset in pandas ( if csv file then _csv & if excel then _excel)

# %%
df1 = pd.read_excel('Bookings-2024.xlsx')

# %%
df2 = pd.read_excel('Bookings2023.xlsx')

# %% [markdown]
# chechking info regarding dataset ( how many rows/columns/datatype )

# %%
df1.info
# Out:
# <bound method DataFrame.info of                      Date      Time     Booking_ID        Booking_Status  \
# 0     2024-07-26 14:00:00  14:00:00  CNR7153255142    Canceled by Driver
# 1     2024-07-25 22:20:00  22:20:00  CNR2940424040               Success
# 2     2024-07-30 19:59:00  19:59:00  CNR2982357879               Success
# 3     2024-07-22 03:15:00  03:15:00  CNR2395710036  Canceled by Customer
# 4     2024-07-02 09:02:00  09:02:00  CNR1797421769               Success
# ...                   ...       ...            ...                   ...
# 20402 2024-07-27 19:46:00  19:46:00  CNR9637947510  Canceled by Customer
# 20403 2024-07-18 05:38:00  05:38:00  CNR4070839222               Success
# 20404 2024-07-25 12:38:00  12:38:00  CNR2768163393               Success
# 20405 2024-07-21 07:58:00  07:58:00  CNR7143313454               Success
# 20406 2024-07-17 02:53:00  02:53:00  CNR4049412680    Canceled by Driver
#
# ...

# %% [markdown]
# Want to check how much null value ( If want replcae = fillna , drop = dropna )

# %%
df1.isnull().sum()
# Out:
# Date                              0
# Time                              0
# Booking_ID                        0
# Booking_Status                    0
# Customer_ID                       0
# Vehicle_Type                      0
# Pickup_Location                   0
# Drop_Location                     0
# V_TAT                          7755
# C_TAT                          7755
# Canceled_Rides_by_Customer    18326
# Canceled_Rides_by_Driver      16753
# Incomplete_Rides               7755
# Incomplete_Rides_Reason       19612
# Booking_Value                     0
# Payment_Method                 7755
# Ride_Distance                     0
# Driver_Ratings                 7755
# Customer_Rating                7755
# Vehicle Images                20407
# dtype: int64

# %%
pecentage_of_missingvalue =df1.isnull().sum()

# %% [markdown]
# finding how much percentage null value per columns

# %%
pecentage_of_missingvalue / len(df1) *100
# Out:
# Date                            0.000000
# Time                            0.000000
# Booking_ID                      0.000000
# Booking_Status                  0.000000
# Customer_ID                     0.000000
# Vehicle_Type                    0.000000
# Pickup_Location                 0.000000
# Drop_Location                   0.000000
# V_TAT                          38.001666
# C_TAT                          38.001666
# Canceled_Rides_by_Customer     89.802519
# Canceled_Rides_by_Driver       82.094379
# Incomplete_Rides               38.001666
# Incomplete_Rides_Reason        96.104278
# Booking_Value                   0.000000
# Payment_Method                 38.001666
# Ride_Distance                   0.000000
# Driver_Ratings                 38.001666
# Customer_Rating                38.001666
# Vehicle Images                100.000000
# dtype: float64

# %%
df1.fillna(0,inplace=True)

# %%
df1.head(100)
# Out:
#                   Date      Time     Booking_ID        Booking_Status  \
# 0  2024-07-26 14:00:00  14:00:00  CNR7153255142    Canceled by Driver
# 1  2024-07-25 22:20:00  22:20:00  CNR2940424040               Success
# 2  2024-07-30 19:59:00  19:59:00  CNR2982357879               Success
# 3  2024-07-22 03:15:00  03:15:00  CNR2395710036  Canceled by Customer
# 4  2024-07-02 09:02:00  09:02:00  CNR1797421769               Success
# ..                 ...       ...            ...                   ...
# 95 2024-07-01 05:03:00  05:03:00  CNR4158584922               Success
# 96 2024-07-23 04:01:00  04:01:00  CNR5133236273    Canceled by Driver
# 97 2024-07-26 08:22:00  08:22:00  CNR5661490576               Success
# 98 2024-07-05 12:36:00  12:36:00  CNR2304446757               Success
# 99 2024-07-18 07:21:00  07:21:00  CNR3780555542  Canceled by Customer
#
#    Customer_ID Vehicle_Type       Pickup_Location     Drop_Location  V_TAT  \
# ...

# %% [markdown]
# checking shape of table how much row and columns

# %%
df1.shape[0]
# Out:
# 20407

# %% [markdown]
# want to know index number

# %%
x = df1 ['Customer_ID'
][0]
x.index('D')
# Out:
# 2

# %% [markdown]
# We want CID as a diffrent columns from customer_id #SCLING

# %%
x = df1['Customer_ID'][0]
x[:x.index("D")]
# Out:
# 'CI'

# %% [markdown]
# WE WANT CID AS DIFFRENT COLUMNS WITH #
# SPILT FUNCTION

# %%
df1['Customer_ID'].str[4:]

# %%
df1['second_part'] = df1['Customer_ID'].str[4:]

# %%
df1.second_part
# Out:
# 0        13523
# 1        25428
# 2        70156
# 3        81320
# 4        39555
#          ...
# 20402    68443
# 20403    02638
# 20404    14557
# 20405    10375
# 20406    20033
# Name: second_part, Length: 20407, dtype: object

# %% [markdown]
# We want add this column in our table (second part )
